# %% [markdown]
# <a href="https://colab.research.google.com/github/Brandao20vtr/Projetos/blob/main/ProjetoMetierAnalise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Humana - Metier

# %%
# !pip install pdfplumber
# Out:
# ...
#      |████████████████████████████████| 5.6 MB 6.6 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 41.2 MB/s
# ...
#      |████████████████████████████████| 139 kB 50.6 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 33.9 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# Importando biblioteca
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pdfplumber
import nltk

# %%
# Carregando o arquivo
pdfMetier = pdfplumber.open('/content/RespostasMetier.pdf')

# %%
# Extraindo as informações dos textos
paginas = pdfMetier.pages[0]
textoCRU = paginas.extract_text()

# Mostrando resuldato
textoCRU
# Out:
# 'Para ganhar espaço no ambiente. Otimização de espaço. Economia de espaço. Otimizar espaço. Geralmente\npara otimizar o espaço. Porque geralmente precisa de uma mesa pequena e prática. Praticidade.\nAproveitamento de espaço. Otimizar o espaço. Otimização de espaço. Home oﬃce, alimentação. Otimizar\nespaço, compra de acordo com tamanho e formato da borda (arredondada). Ganhar espaço e mobilidade,\npois pode instalar em uma altura diferente das mesas convencionais. Conseguir ter uma mesa de apoio em\nqualquer espaço porque é prática e pode baixar, deixando o ambiente livre para uso. Geralmente para estudo\nou trabalho. Flexibilidade e praticidade. Não tem um gênero que procura mais que outro, idade entre 30 e 60\nanos. Todos só tipos. Geralmente meia idade. Diverso. Homens e mulheres, maioria que atendi com idade de\n30-40 anos. Temos publico para esse produto em todos gêneros e idade. Homens e Mulheres com ﬁlhos na\nescola ( para estudos) ou para área de churrasco, ou apoio para cozin
# ...

# %%
# Quebrando o texto em palavras individuais
nltk.download('punkt')
lista_de_palavras = nltk.tokenize.word_tokenize(textoCRU)
lista_de_palavras
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['Para',
#  'ganhar',
#  'espaço',
#  'no',
#  'ambiente',
#  '.',
#  'Otimização',
#  'de',
#  'espaço',
#  '.',
#  'Economia',
#  'de',
#  'espaço',
#  '.',
#  'Otimizar',
#  'espaço',
#  '.',
#  'Geralmente',
#  'para',
#  'otimizar',
#  'o',
#  'espaço',
#  '.',
#  'Porque',
#  'geralmente',
#  'precisa',
#  'de',
#  'uma',
#  'mesa',
#  'pequena',
#  'e',
#  'prática',
#  '.',
#  'Praticidade',
#  '.',
#  'Aproveitamento',
#  'de',
#  'espaço',
#  '.',
#  'Otimizar',
#  'o',
#  'espaço',
#  '.',
#  'Otimização',
#  'de',
#  'espaço',
#  '.',
#  'Home',
#  'oﬃce',
#  ',',
#  'alimentação',
#  '.',
#  'Otimizar',
#  'espaço',
#  ',',
#  'compra',
#  'de',
#  'acordo',
#  'com',
#  'tamanho',
#  'e',
#  'formato',
#  'da',
#  'borda',
#  '(',
#  'arredondada',
#  ')',
#  '.',
#  'Ganhar',
#  'espaço',
#  'e',
#  'mobilidade',
#  ',',
#  'pois',
#  'pode',
# ...

# %%
# Transformando todas as palavra em minúsculas
lista_de_palavras = [palavra.lower() for palavra in lista_de_palavras]
lista_de_palavras
# Out:
# ['para',
#  'ganhar',
#  'espaço',
#  'no',
#  'ambiente',
#  '.',
#  'otimização',
#  'de',
#  'espaço',
#  '.',
#  'economia',
#  'de',
#  'espaço',
#  '.',
#  'otimizar',
#  'espaço',
#  '.',
#  'geralmente',
#  'para',
#  'otimizar',
#  'o',
#  'espaço',
#  '.',
#  'porque',
#  'geralmente',
#  'precisa',
#  'de',
#  'uma',
#  'mesa',
#  'pequena',
#  'e',
#  'prática',
#  '.',
#  'praticidade',
#  '.',
#  'aproveitamento',
#  'de',
#  'espaço',
#  '.',
#  'otimizar',
#  'o',
#  'espaço',
#  '.',
#  'otimização',
#  'de',
#  'espaço',
#  '.',
#  'home',
#  'oﬃce',
#  ',',
#  'alimentação',
#  '.',
#  'otimizar',
#  'espaço',
#  ',',
#  'compra',
#  'de',
#  'acordo',
#  'com',
#  'tamanho',
#  'e',
#  'formato',
#  'da',
#  'borda',
#  '(',
#  'arredondada',
#  ')',
#  '.',
#  'ganhar',
#  'espaço',
#  'e',
#  'mobilidade',
#  ',',
#  'pois',
#  'pode',
#  'instalar',
#  'em',
#  'uma',
#  'altura',
#  'diferente',
#  'das',
#  'mesas',
#  'convencionais',
#  '.',
# ...

# %%
# Criando uma lista que contêm pontuação que desejamos remover
pontuacao = ['(', ')', ';', ':', '[', ']', ',', '.', '?', '/', 'x', "''", "``"]

# %%
# Criando uma lista de stop word
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('portuguese')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['de',
#  'a',
#  'o',
#  'que',
#  'e',
#  'é',
#  'do',
#  'da',
#  'em',
#  'um',
#  'para',
#  'com',
#  'não',
#  'uma',
#  'os',
#  'no',
#  'se',
#  'na',
#  'por',
#  'mais',
#  'as',
#  'dos',
#  'como',
#  'mas',
#  'ao',
#  'ele',
#  'das',
#  'à',
#  'seu',
#  'sua',
#  'ou',
#  'quando',
#  'muito',
#  'nos',
#  'já',
#  'eu',
#  'também',
#  'só',
#  'pelo',
#  'pela',
#  'até',
#  'isso',
#  'ela',
#  'entre',
#  'depois',
#  'sem',
#  'mesmo',
#  'aos',
#  'seus',
#  'quem',
#  'nas',
#  'me',
#  'esse',
#  'eles',
#  'você',
#  'essa',
#  'num',
#  'nem',
#  'suas',
#  'meu',
#  'às',
#  'minha',
#  'numa',
#  'pelos',
#  'elas',
#  'qual',
#  'nós',
#  'lhe',
#  'deles',
#  'essas',
#  'esses',
#  'pelas',
#  'este',
#  'dele',
#  'tu',
#  'te',
#  'vocês',
#  'vos',
#  'lhes',
#  'meus',
#  'minhas',
#  'teu',
#  'tua',
#  'teus',
#  'tuas',
# ...

# %%
# Criando uma lista de palavras sem stopword e pontuações
keywords = [palavra 
            for palavra in lista_de_palavras 
            if not palavra in stop_words and not palavra in pontuacao]
keywords
# Out:
# ['ganhar',
#  'espaço',
#  'ambiente',
#  'otimização',
#  'espaço',
#  'economia',
#  'espaço',
#  'otimizar',
#  'espaço',
#  'geralmente',
#  'otimizar',
#  'espaço',
#  'porque',
#  'geralmente',
#  'precisa',
#  'mesa',
#  'pequena',
#  'prática',
#  'praticidade',
#  'aproveitamento',
#  'espaço',
#  'otimizar',
#  'espaço',
#  'otimização',
#  'espaço',
#  'home',
#  'oﬃce',
#  'alimentação',
#  'otimizar',
#  'espaço',
#  'compra',
#  'acordo',
#  'tamanho',
#  'formato',
#  'borda',
#  'arredondada',
#  'ganhar',
#  'espaço',
#  'mobilidade',
#  'pois',
#  'pode',
#  'instalar',
#  'altura',
#  'diferente',
#  'mesas',
#  'convencionais',
#  'conseguir',
#  'ter',
#  'mesa',
#  'apoio',
#  'qualquer',
#  'espaço',
#  'porque',
#  'prática',
#  'pode',
#  'baixar',
#  'deixando',
#  'ambiente',
#  'livre',
#  'uso',
#  'geralmente',
#  'estudo',
#  'trabalho',
#  'flexibilidade',
#  'praticidade',
#  'gênero',
#  'procura',
#  'outro',
#  'idade',
#  '30',
#  '60',
# ...

# %%
# Contando as palavras
len(keywords)
# Out:
# 385

# %%
# Concatenando as palavras
textoMetier = ' '.join(s for s in keywords)
textoMetier
# Out:
# 'ganhar espaço ambiente otimização espaço economia espaço otimizar espaço geralmente otimizar espaço porque geralmente precisa mesa pequena prática praticidade aproveitamento espaço otimizar espaço otimização espaço home oﬃce alimentação otimizar espaço compra acordo tamanho formato borda arredondada ganhar espaço mobilidade pois pode instalar altura diferente mesas convencionais conseguir ter mesa apoio qualquer espaço porque prática pode baixar deixando ambiente livre uso geralmente estudo trabalho flexibilidade praticidade gênero procura outro idade 30 60 anos todos tipos geralmente meia idade diverso homens mulheres maioria atendi idade 30-40 anos publico produto todos gêneros idade homens mulheres ﬁlhos escola estudos área churrasco apoio cozinha 25 45 anos homens 25 40 anos estudantes pouco espaço destinado mesa trabalho estudo homens 25 40 anos lado visibilidade boa hoje vertical frente pé mostruário acima maioria pé melhor visualização todos modelos disponíveis empresa expost
# ...

# %% [markdown]
# # Gerando Núvem de Palavras

# %%
# Núvem de Palavras de todas as perguntas
wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(textoMetier)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # Núvem de Palavra sobre cade pergunta

# %% [markdown]
# # 1. Porque o cliente compra mesa de parede?

# %%
# Resposta 1
p1 = ('para ganhar espaço no ambiente \
otimização de espaço \
economia de espaço \
otimizar espaço \
geralmente para otimizar o espaço \
porque geralmente precisa de uma mesa pequena e prática \
praticidade \
aproveitamento de espaço \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p1)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 2. Qual a necessidade do cliente ao comprar?

# %%
# Resposta 2
p2 = ('otimizar o espaço \
otimização de espaço \
homeoffice alimentação \
otimizar espaço compra de acordo com tamanho e formato da borda \
ganhar espaço e mobilidade pois pode instalar em uma altura diferente das mesas convencionais \
conseguir ter uma mesa de apoio em qualquer espaço porque é prática e pode baixar deixando o ambiente livre para uso \
geralmente para estudo ou trabalho \
flexibilidade e praticidade \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p2)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 3. Quem é o cliente? Qual o gênero que mais procura? Qual a Idade?

# %%
# Resposta 3
p3 = ('não tem um gênero que procura mais que outro idade entre trinta a sesenta anos \
todos só tipos geralmente meia idade \
diverso homens e mulheres maioria que atendi com idade de trinta a quarenta anos \
temos publico para esse produto em todos gêneros e idade \
homens e mulheres com filhos na escola ou para área de churrasco ou apoio para cozinha vintecinco a quarentacinco anos \
homens entre vintecindo a quarenta anos \
estudantes com pouco espaço destinado a mesa de trabalho estudo homens entre vintecinco a quarenta anos \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p3)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 4. Como o produto está disposto na prateleira?

# %%
# Resposta 4
p4 = ('de lado visibilidade não e boa hoje \
na vertical de frente \
vertical com mostruário acima \
vertical para melhor visualização \
temos todos os modelos disponíveis na empresa expostos no linear e um modelo na ponta de gôndola esporadicamente \
vertical separado por cor e tamanho \
somente no linear \
vertical \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p4)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 5. Qual a marca que ele compra?

# %%
# Resposta 5
p5 = ('não tem preferencia de marca \
não tem marca preferida compra a necessidade \
nunca me procuraram por marca específica \
não temos uma marca preferida pelo cliente geralmente temos uma procura maior pelo modelo da trava \
geralmente não escolhe marca \
não tem preferencia de marca \
multivisão e bemfixa \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p5)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 6. Qual a cor que mais vende e menos vende?

# %%
# Resposta 6
p6 = ('branca amadeirado \
branca menos vende preta \
branca \
castanho \
branca as vezes preta ou marrom \
as cores que mais vende são branca e preta, e a castanho é a que menos vende \
branca vende mais temos a preta com boa aceitação só trabalhamos com as duas cores \
preta \
branca \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p6)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 7. Quais as perguntas do produto que o cliente faz quando vai comprar?

# %%
# Resposta 7
p7 = ('se realmente é funcional \
como dobra é fácil instalar \
como instalar \
se ela dobra \
carga que suporta \
tamanho borda  como funciona o mecanismo de dobrar a mesa \
os clientes perguntam muito sobre como é a instalação do produto \
Se temos o tamanho que ele procura e como funciona o suporte \
sobre a capacidade de peso da mesa \
qual o peso máximo suportado pela mesma \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p7)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 8. Quais principais dificuldades o cliente tem quando vai comprar?

# %%
# Resposta 8
p8 = ('saber como funciona tive que instalar uma para facilitar \
mostruário que der para ver o funcionamento \
item bem simples não vejo dificuldades \
encontrar no tamanho necessário específico que quer com borda arredondada \
normalmente é tem falta de espaço no ambiente onde vai utilizar o produto \
entender como funciona o suporte \
acha caro \
instalação segura \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p8)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 9. Quais principais dificuldades que a equipe da loja tem para vender o produto?

# %%
# Resposta 9
p9 = ('a embalagem é horrível e perde venda \
por ser um linear pequeno não dar para colocar um mostruário \
hoje acredito que a disposição que o material se encontra no linear \
sem dificuldades relatadas \
não consigo ver uma dificuldade na hora de vender a mesa de parede dobrável já a fixa temos uma resistência do cliente no preço do produto \
a venda é simples Faltam opções de cores tirar similaridade e incluir tons de madeira que combinem com nossas prateleiras para fechar um projeto simples\
a dificuldade da equipe é entender a solicitação do cliente \
preço pois dispusemos de prateleiras e braços que executam a mesma finalidade\
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p9)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 10. Como é o estoque desse produto? Sempre tem quando o cliente compra ou tem que encomendar?

# %%
# Resposta 10
p10 = ('sempre tem \
tem de pronta entrega \
disponível em loja \
sempre temos disponibilidade \
estoque disponível ao cliente \
disponível em loja e pronta entrega \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p10)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # 11. Comportamento do cliente em frente a esse produto?

# %%
# Resposta 11
p11 = ('dificuldade em entender o produto \
normal \
compra muito rápida geralmente já tem a medida quando não tem liga e compra a que atende os mesmo pelo tamanho \
nada específico \
geralmente o cliente fica satisfeito com a qualidade do produto \
quando o tamanho e a cor atendem o esperado o cliente geralmente leva o produto tranquilamente \
não é de surpresa \
o cliente encontra neste produto a solução pra uma demanda complexa espaco e praticidade \
')


wordcloud = WordCloud(background_color = '#0f54c9',
                      max_font_size = 150,
                      width = 1280,
                      height = 720,
                      colormap = 'Blues').generate(p11)

fig, ax = plt.subplots(figsize = (16, 9))
ax.imshow(wordcloud)
ax.set_axis_off()
plt.imshow(wordcloud)
plt.show()
